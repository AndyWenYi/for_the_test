# %%
from pyspark.sql import SparkSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/xc/vycysf7n7dsdx6vwj8hh92p80000gn/T/ipykernel_89461/3448758925.py in <module>
# ----> 1 from pyspark.sql import SparkSession
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
import pandas as pd 
df = pd.read_csv('A_lvr_land_A.csv')
for i in df['建物型態'].to_list():
    if '住宅大樓' in i:
        print(i)
# Out:
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# 住宅大樓(11層含以上有電梯)
# ...

# %%
for i in df['建物型態'].to_list():
    if i == '住宅大樓':
        print(i)

# %%
df['建物型態']
# Out:
# 0        building state
# 1       住宅大樓(11層含以上有電梯)
# 2       住宅大樓(11層含以上有電梯)
# 3                    其他
# 4          公寓(5樓含以下無電梯)
#              ...
# 5591    住宅大樓(11層含以上有電梯)
# 5592    住宅大樓(11層含以上有電梯)
# 5593             店面(店鋪)
# 5594    住宅大樓(11層含以上有電梯)
# 5595    住宅大樓(11層含以上有電梯)
# Name: 建物型態, Length: 5596, dtype: object
